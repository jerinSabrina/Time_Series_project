# %% [markdown]
# <a href="https://colab.research.google.com/github/jerinSabrina/Time_Series_project/blob/main/Project_1_Time_Series_Analysis_of_Wastewater_Treatment_Plant_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install statsmodels
# !pip install kaggle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("Everything is working!")
# Out:
# Everything is working!
